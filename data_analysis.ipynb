# %% [markdown]
# ### YDATA-PROFILING - Data Profiling With Pandas
# Run this notebook in a different environment than the assessments responses. There are package conflicts that could not be resolved when duckdb is installed (used to respond to question 2).

# %%
# Imports

import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# Running cells with 'dataprofiling' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n dataprofiling ipykernel --update-deps --force-reinstall'

# %%
# Profile Claims

df_claims = pd.read_csv("data\\sample_claims.csv", na_filter=False)
profile = ProfileReport(df_claims, title="Claims Profiling Report")
profile.to_notebook_iframe()
# Out:
# Running cells with 'dataprofiling' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n dataprofiling ipykernel --update-deps --force-reinstall'

# %%
# Profile Procedure Concept Codes

df_codes_cpt = pd.read_csv("data\\valid_cpt_codes.csv", na_filter=False)
profile = ProfileReport(df_codes_cpt, title="CPT Codes Profiling Report")
profile.to_notebook_iframe()
# Out:
# Running cells with 'dataprofiling' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n dataprofiling ipykernel --update-deps --force-reinstall'

# %%
# Profile ICD 10 Codes

df_codes_icd = pd.read_csv("data\\valid_icd_10_codes.csv", na_filter=False)
profile = ProfileReport(df_codes_icd, title="ICD 10 Profiling Report")
profile.to_notebook_iframe()
# Out:
# Running cells with 'dataprofiling' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n dataprofiling ipykernel --update-deps --force-reinstall'
